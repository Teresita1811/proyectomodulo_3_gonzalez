# %% [markdown]
# # Lorenz

# %% [markdown]
# # Objetivos
# ### Objetivos  generales
#    + Resolver una o varias ecuaciones diferenciales, que sean complejas, con python.
# ### Objetivos específicos
#    + Objetivo manual: Aprender a graficar en un plano y de manera 3D, el comportamiento de la solución de ecuaciones diferenciales.

# %% [markdown]
# ![imagen.png](aa.png)

# %% [markdown]
# A continuación utilizaremos el modelo de ecuaciones de Lorenz, teoría que nos presenta la duda de que tantos cambios hacen las condiciones iniciales a largo plazo, para eso plantearemos la función, definiremos 2 tipos de casos ya definidos y comprobados donde podremos ver los cambios en las condiciones iniciales.

# %%
#Importamos las librerias
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.integrate import odeint
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
#  El siguiente atractor está dado por las condiciones iniciales a =10, b= 28, c= 8/3.

# %%
# Definimos la función que nos ayudara a resolver las ecuaciones simplificadas de Lorenz
def atractor_lorenz(X,t):
    x = X[0]
    y = X[1]
    z = X[2]
 # Condiciones iniciales    
    a = 10
    b = 28
    c=8/3
#Ecuaciones a resolver  
    dx = a*(y-x)
    dy = x*(b-z)-y
    dz = x*y -c*z
#Las colocamos en un vector
    return np.array([dx,dy,dz])

# %%
#Condicion inicial del vector
x0 = np.array([1,1,1])
# El vector del tiempo
t = np.linspace(0,50,5000)
#Linea que soluciona las ecuaciones
sol = odeint(atractor_lorenz,x0,t)

# %%
# Cada una de las soluciones
x = sol[:,0]
y = sol[:,1]
z = sol[:,2]

# %%
plt.figure(figsize=(8,6))
#plt.plot(y,x)
#plt.show()

#Crear gráfica en 3d y definir tamaño
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111, projection='3d')


ax.plot(sol[:,0], sol[:,1], sol[:,2],'-k',ms=1 )
plt.show()

# %% [markdown]
# Se muestran órbitas periódicas para estos valores de b.

# %% [markdown]
# Las condiciones iniciales para la siguiente muestra son a=10, b=99.96, c=8/3.

# %%
def atractor_lorenz99(Q,r):
    q = Q[0]
    w = Q[1]
    e = Q[2]
    
    l = 10
    m = 99.96
    ñ=8/3
    
    dex = l*(w-q)
    dey = q*(m-e)-w
    dez = q*w -ñ*e
    
    return np.array([dex,dey,dez])

# %%
c0 = np.array([1,1,1])
r = np.linspace(0,50,5000)

sole = odeint(atractor_lorenz99,c0,r)

q = sole[:,0]
w = sole[:,1]
e = sole[:,2]

# %%
#Crear gráfica y definir tamaño
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111, projection='3d')


ax.plot(sole[:,0], sole[:,1], sole[:,2],'-k',ms=1 )
plt.show()

# %% [markdown]
# Se convierte en un nudo tórico llamado T(3,2). Se ve cómo cambia a modo que cambia la condición b

# %% [markdown]
# ## Conclusión
# Pudimos observar como un cambio pero solo e las trayectorias finales que es donde se toman otros cursos, y hacen que estos pequeños cambion sean significativos, a largo plazo.
